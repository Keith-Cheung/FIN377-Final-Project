# %%
import pandas as pd

# %%
WFH_Industry = pd.read_csv('Work From Home Data/Industry_WFH\WFH_Industry.csv')
startup_Industry = pd.read_csv('Startup Data/Industry/bfs_monthly.csv')
#startup_Industry.dtypes
startup_Industry = startup_Industry[startup_Industry['year'] >= 2015]
startup_Industry['naics_sector'].replace('NAICS22', 'Utilities')
startup_Industry
# Out:
# C:\Users\keith\AppData\Local\Temp\ipykernel_3460\1106875115.py:2: DtypeWarning: Columns (5,6,7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   startup_Industry = pd.read_csv('Startup Data/Industry/bfs_monthly.csv')
#       sa naics_sector    series geo  year     jan     feb     mar   apr   may  \
# 0      U        TOTAL     BA_BA  US  2024  574930  455499  467910   NaN   NaN
# 1      U      NAICS11     BA_BA  US  2024   10993   10111    6668   NaN   NaN
# 2      U      NAICS21     BA_BA  US  2024     719     467     559   NaN   NaN
# 3      U      NAICS22     BA_BA  US  2024     748     595     738   NaN   NaN
# 4      U      NAICS23     BA_BA  US  2024   54517   45940   46573   NaN   NaN
# ...   ..          ...       ...  ..   ...     ...     ...     ...   ...   ...
# 14663  U        TOTAL  BF_DUR8Q  VA  2015    1.60    2.02    2.29  1.85  2.03
# 14664  U        TOTAL  BF_DUR8Q  WA  2015    1.42    1.78    2.05  1.65  1.99
# ...

# %%
WFH_Industry = WFH_Industry[WFH_Industry.columns.drop(list(WFH_Industry.filter(regex='full_onsite')))]
WFH_Industry = WFH_Industry[WFH_Industry.columns.drop(list(WFH_Industry.filter(regex='hybrid')))]
WFH_Industry
# Out:
#          date  full_remote_arts_entertain  full_remote_education  \
# 0   11/1/2021                        26.4                   12.2
# 1   12/1/2021                        25.0                   13.3
# 2    1/1/2022                        24.3                   13.6
# 3    2/1/2022                        23.7                   13.0
# 4    3/1/2022                        23.3                   10.0
# 5    4/1/2022                        23.5                   10.2
# 6    5/1/2022                        19.3                    9.7
# 7    6/1/2022                        18.2                   12.6
# 8    7/1/2022                        21.8                   12.5
# 9    8/1/2022                        20.2                   11.7
# 10   9/1/2022                        20.1                   10.1
# 11  10/1/2022                        18.2                    8.8
# 12  11/1/2022                        15.1                    9.8
# ...

# %%
'''WFH_Industry['date'] = pd.to_datetime(WFH_Industry['date'])
WFH_Industry['year'] = WFH_Industry['date'].dt.year
months = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
for month in months:
    WFH_Industry[month] = WFH_Industry['date'].dt.month_name() == month

WFH_Industry_long = pd.melt(WFH_Industry, id_vars = ['year'], value_vars=months, var_name= 'month', value_name='Value')
#WFH_Industry_long
WFH_Industry_wide = WFH_Industry_long.pivot_table(index = 'year', columns='month', values = 'Value', aggfunc = 'first').reset_index()
WFH_Industry_wide'''
# Out:
# month  year    apr    aug    dec    feb    jan    jul    jun    mar    may  \
# 0      2021  False  False  False  False  False  False  False  False  False
# 1      2022  False  False  False  False  False  False  False  False  False
# 2      2023  False  False  False  False  False  False  False  False  False
# 3      2024  False  False  False  False  False  False  False  False  False
#
# month    nov    oct    sep
# 0      False  False  False
# 1      False  False  False
# 2      False  False  False
# 3      False  False  False

# %%
'''WFH_Industry['date'] = pd.to_datetime(WFH_Industry['date'])
WFH_Industry['year'] = WFH_Industry['date'].dt.year
WFH_Industry['month'] = WFH_Industry['date'].dt.month_name().str.slice(stop = 3)

WFH_Industry_pivot = WFH_Industry.pivot_table(index = ['year'], columns = 'month', values=['full_remote_arts_entertain', 'full_remote_education', 'full_remote_finance_insurance', 'full_remote_government', 'full_remote_healthcare', 
                                                                                                     'full_remote_hospitaility_food', 'full_remote_information', 'full_remote_manufacturing', 'full_remote_prof_bus_services', 'full_remote_realestate', 'full_remote_retail',
                                                                                                       'full_remote_transp_warehousing', 'full_remote_utilities', 'full_remote_wholesale'] )

WFH_Industry_pivot.columns = ['_'.join(col).rstrip('_') for col in WFH_Industry_pivot.columns.values]
WFH_Industry_pivot.reset_index(inplace=True)
#WFH_Industry_pivot = WFH_Industry_pivot[['sector', 'year', 'jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']]
WFH_Industry_pivot'''
# Out:
# "WFH_Industry['date'] = pd.to_datetime(WFH_Industry['date'])\nWFH_Industry['year'] = WFH_Industry['date'].dt.year\nWFH_Industry['month'] = WFH_Industry['date'].dt.month_name().str.slice(stop = 3)\n\nWFH_Industry_pivot = WFH_Industry.pivot_table(index = ['year'], columns = 'month', values=['full_remote_arts_entertain', 'full_remote_education', 'full_remote_finance_insurance', 'full_remote_government', 'full_remote_healthcare', \n                                                                                                     'full_remote_hospitaility_food', 'full_remote_information', 'full_remote_manufacturing', 'full_remote_prof_bus_services', 'full_remote_realestate', 'full_remote_retail',\n                                                                                                       'full_remote_transp_warehousing', 'full_remote_utilities', 'full_remote_wholesale'] )\n\nWFH_Industry_pivot.columns = ['_'.join(col).rstrip('_') for col in WFH_Industry_pivot.columns.values]\
# ...

# %%
WFH_Industry_T = WFH_Industry.T
WFH_Industry_T
# Out:
#                                                                                0   \
# date                                                                    11/1/2021
# full_remote_arts_entertain                                                   26.4
# full_remote_education                                                        12.2
# full_remote_finance_insurance                                                26.9
# full_remote_government                                                       12.8
# full_remote_healthcare                                                       16.4
# full_remote_hospitaility_food                                                 3.3
# full_remote_information                                                      15.1
# full_remote_manufacturing                                                     6.2
# full_remote_prof_bus_services                                                27.2
# ...

# %%
# Out:
#          date full_remote_arts_entertain full_remote_education  \
# 0   11/1/2021                       26.4                  12.2
# 1   12/1/2021                       25.0                  13.3
# 2    1/1/2022                       24.3                  13.6
# 3    2/1/2022                       23.7                  13.0
# 4    3/1/2022                       23.3                  10.0
# 5    4/1/2022                       23.5                  10.2
# 6    5/1/2022                       19.3                   9.7
# 7    6/1/2022                       18.2                  12.6
# 8    7/1/2022                       21.8                  12.5
# 9    8/1/2022                       20.2                  11.7
# 10   9/1/2022                       20.1                  10.1
# 11  10/1/2022                       18.2                   8.8
# 12  11/1/2022                       15.1                   9.8
# 13  12/1/2022                       16.0                   9.3
# ...
